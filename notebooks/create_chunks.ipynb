# %%
import sys, os, re
import pyranges as pr
import pandas as pd

# %%
genome_fa =  "AmexG_v6.0-DD.fa"                                                                                                                 
out_prefix = "ladeda"                                                                                                                       
chunks_file = "chunks.tsv"

# %%
                                                                                                      
genome_fai_file = genome_fa + ".fai"                                                                                                               
genome_contig_info = pd.read_csv(genome_fai_file, sep="\t", 
                                 names=["Chromosome", "Length", "Offset", "Linebases", "Linewidth"])                                                                                                                                                                          
chromosomes = genome_contig_info['Chromosome'].values.tolist()     

genome_contig_info.head()
# Out:
#   Chromosome      Length      Offset  Linebases  Linewidth
# 0     chr10p  1082275901           8         80         81
# 1     chr10q   525957290  1095804366         80         81
# 2     chr11p   305732125  1628336131         80         81
# 3     chr11q  1079741261  1937889916         80         81
# 4     chr12p   289110169  3031127951         80         81

# %%
chr_lengths = dict()

for x in genome_contig_info.itertuples():
    chr_lengths[ x.Chromosome]  = x.Length

# %%
                                                                                                                                                     
chunks = pd.read_csv(chunks_file, sep="\t") 

chunks.head()
# Out:
#   Chromosome      brkpt  chunksize_offset_frac
# 0     chr10p  360766498               0.000016
# 1     chr10p  721257583               0.000519
# 2     chr10q  263007889               0.000058
# 3     chr11q  358409797               0.003008
# 4     chr11q  719828585               0.000002

# %%
annotation_gtf = pd.read_csv("AmexT_v47-AmexG_v6.0-DD.gtf", sep="\t", names=[
    "Chromosome", "Source", "ev_type", "Start", "End", "Score", "Strand", "dot", "info"])

# %%
chromosomes_need_chunking = chunks['Chromosome'].unique().tolist()
chromosomes_need_chunking
# Out:
# ['chr10p',
#  'chr10q',
#  'chr11q',
#  'chr12q',
#  'chr1p',
#  'chr1q',
#  'chr2p',
#  'chr2q',
#  'chr3p',
#  'chr3q',
#  'chr4p',
#  'chr4q',
#  'chr5p',
#  'chr5q',
#  'chr6p',
#  'chr6q',
#  'chr7p',
#  'chr7q',
#  'chr8p',
#  'chr8q',
#  'chr9q']

# %%
chromosome_to_chunk = chromosomes_need_chunking[0]

# %%
chr_gtf = annotation_gtf[ annotation_gtf.Chromosome == chromosome_to_chunk ]

chr_gtf.head()
# Out:
#   Chromosome      Source     ev_type   Start     End  Score Strand dot  \
# 0     chr10p  ambMex60DD        gene  313039  315424   1000      +   .
# 1     chr10p  ambMex60DD  transcript  313039  315424   1000      +   .
# 2     chr10p  ambMex60DD        exon  313039  314183   1000      +   .
# 3     chr10p  ambMex60DD        exon  315024  315424   1000      +   .
# 4     chr10p  ambMex60DD  transcript  313800  315023   1000      +   .
#
#                                                 info
# 0  gene_id "AMEX60DD000001"; gene_name "ZFP37 [nr...
# 1  gene_id "AMEX60DD000001"; transcript_id "ZFP37...
# 2  gene_id "AMEX60DD000001"; transcript_id "ZFP37...
# 3  gene_id "AMEX60DD000001"; transcript_id "ZFP37...
# 4  gene_id "AMEX60DD000001"; transcript_id "ZNF79...

# %%
breakpoints = chunks[chunks.Chromosome == chromosome_to_chunk ]['brkpt'].values

breakpoints = sorted(breakpoints)

breakpoints.insert(0, 0)
breakpoints.append(chr_lengths[chromosome_to_chunk])

breakpoints
# Out:
# [0, 360766498, 721257583, 1082275901]

# %%
partitioned_chrom_df = None
for i in range(len(breakpoints)-1):
    lend_brkpt = breakpoints[i]
    rend_brkpt = breakpoints[i+1]
    print(lend_brkpt, rend_brkpt)
    
    chrom_partition_name = chromosome_to_chunk + f"^c{i}^o{lend_brkpt}"
    
    chr_gtf_partition = chr_gtf[ (chr_gtf.Start >= lend_brkpt) & (chr_gtf.End < rend_brkpt) ].copy()
    print(chr_gtf_partition.shape)
    
    # make adjustment to the gtf partition
    chr_gtf_partition['Chromosome'] = chrom_partition_name
    if lend_brkpt != 0:
        chr_gtf_partition['Start'] = chr_gtf_partition.Start - lend_brkpt
        chr_gtf_partition['End'] = chr_gtf_partition.End - lend_brkpt
        
    partitioned_chrom_df = pd.concat([partitioned_chrom_df, chr_gtf_partition])
    
    
partitioned_chrom_df
# Out:
# 0 360766498
# (30691, 9)
# 360766498 721257583
# (22588, 9)
# 721257583 1082275901
# (17884, 9)
#                  Chromosome      Source     ev_type      Start        End  \
# 0              chr10p^c0^o0  ambMex60DD        gene     313039     315424
# 1              chr10p^c0^o0  ambMex60DD  transcript     313039     315424
# 2              chr10p^c0^o0  ambMex60DD        exon     313039     314183
# 3              chr10p^c0^o0  ambMex60DD        exon     315024     315424
# 4              chr10p^c0^o0  ambMex60DD  transcript     313800     315023
# ...                     ...         ...         ...        ...        ...
# 71158  chr10p^c2^o721257583  ambMex60DD         CDS  360598108  360598226
# 71159  chr10p^c2^o721257583  ambMex60DD         CDS  360685489  360685531
# 71160  chr10p^c2^o721257583  ambMex60DD        gene  360695766  360695965
# 71161  chr10p^c2^o721257583  ambMex60DD  transcript  360695766  360695965
# 71162  chr10p^c2^o721257583  ambMex60DD        exon  360695766  360695965
#
#        Score Strand dot                                               info
# 0       1000      +   .  gene_id "AMEX60DD000001"; gene_name "ZFP37 [nr...
# 1       1000      +   .  gene_id "AMEX60DD000001"; transcript_id "ZFP37...
# 2       1000      +   .  gene_id "AMEX60DD000001"; transcript_id "ZFP37...
# 3       1000      +   .  gene_id "AMEX60DD000001"; transcript_id "ZFP37...
# 4       1000      +   .  gene_id "AMEX60DD000001"; transcript_id "ZNF79...
# ...      ...    ...  ..                                                ...
# 71158   1000      +   .  gene_id "AMEX60DD002204"; transcript_id "LOC10...
# 71159   1000      +   .  gene_id "AMEX60DD002204"; transcript_id "LOC10...
# 71160   1000      +   .  gene_id "AMEX60DD002205"; gene_name "AMEX60DD0...
# 71161   1000      +   .  gene_id "AMEX60DD002205"; transcript_id "AMEX6...
# 71162   1000      +   .  gene_id "AMEX60DD002205"; transcript_id "AMEX6...
#
# [71163 rows x 9 columns]

# %%
[chrom for chrom in chromosomes if chrom not in chromosomes_need_chunking]
# Out:
# ['chr11p',
#  'chr12p',
#  'chr13p',
#  'chr13q',
#  'chr14p',
#  'chr14q',
#  'chr9p',
#  'C0128467',
#  'C0128569',
#  'C0128574',
#  'C0128687',
#  'C0128715',
#  'C0128790',
#  'C0128851',
#  'C0128909',
#  'C0128923',
#  'C0129016',
#  'C0129038',
#  'C0129066',
#  'C0129093',
#  'C0129146',
#  'C0129181',
#  'C0129217',
#  'C0129219',
#  'C0129252',
#  'C0129279',
#  'C0129288',
#  'C0129302',
#  'C0129304',
#  'C0129315',
#  'C0129323',
#  'C0129458',
#  'C0129529',
#  'C0129583',
#  'C0129600',
#  'C0129681',
#  'C0129705',
#  'C0129855',
#  'C0129944',
#  'C0130288',
#  'C0130458',
#  'C0130541',
#  'C0130758',
#  'C0130922',
#  'C0131115',
#  'C0131119',
#  'C0131185',
#  'C0131218',
#  'C0131234',
#  'C0131257',
#  'C0131269',
#  'C0131338',
#  'C0131357',
#  'C0131362',
#  'C0131400',
#  'C0131426',
#  'C0131549',
#  'C0131557',
#  'C0131725',
#  'C0131753',
#  'C0131828',
#  'C0131834',
#  'C0131869',
#  'C0131871',
#  'C0131996',
#  'C0132009',
#  'C0132040',
#  'C0132054',
#  'C0132069',
#  'C0132119',
#  'C0132131',
#  'C0132252',
#  'C0132311',
#  'C0132394',
#  'C0132416',
#  'C0132423',
#  'C0132441',
#  'C0132452',
#  'C0132562',
#  'C0132724',
#  'C0132773',
#  'C0132797',
#  'C0132802',
#  'C0132920',
#  'C0132987',
#  'C0132998',
#  'C0133003',
#  'C0133037',
#  'C0133062',
#  'C0133085',
#  'C0133122',
#  'C0133306',
#  'C0133594',
#  'C0133705',
#  'C0133721',
#  'C0133791',
#  'C0133807',
#  'C0133811',
#  'C0133881',
#  'C0133891',
#  'C0133959',
#  'C0134066',
#  'C0134177',
#  'C0134210',
#  'C0134366',
#  'C0134431',
#  'C0134468',
#  'C0134476',
#  'C0134521',
#  'C0134588',
#  'C0134590',
#  'C0134660',
#  'C0134782',
#  'C0134789',
#  'C0134822',
#  'C0134825',
#  'C0134875',
#  'C0134886',
#  'C0135036',
#  'C0135082',
#  'C0135145',
#  'C0135253',
#  'C0135279',
#  'C0135293',
#  'C0135294',
#  'C0135311',
#  'C0135317',
#  'C0135335',
#  'C0135373',
#  'C0135375',
#  'C0135445',
#  'C0135537',
#  'C0135664',
#  'C0135683',
#  'C0135725',
#  'C0135772',
#  'C0135808',
#  'C0135950',
#  'C0136023',
#  'C0136254',
#  'C0136255',
#  'C0136379',
#  'C0136433',
#  'C0136445',
#  'C0136594',
#  'C0136657',
#  'C0136677',
#  'C0136692',
#  'C0136769',
#  'C0136804',
#  'C0136865',
#  'C0136956',
#  'C0137073',
#  'C0137111',
#  'C0137153',
#  'C0137410',
#  'C0137430',
#  'C0137451',
#  'C0137457',
#  'C0137490',
#  'C0137744',
#  'C0137789',
#  'C0137793',
#  'C0137811',
#  'C0137864',
#  'C0138051',
#  'C0138141',
#  'C0138204',
#  'C0138237',
#  'C0138391',
#  'C0138460',
#  'C0138501',
#  'C0138736',
#  'C0138878',
#  'C0139048',
#  'C0139051',
#  'C0139230',
#  'C0139238',
#  'C0139242',
#  'C0139264',
#  'C0139309',
#  'C0139465',
#  'C0139624',
#  'C0139661',
#  'C0139730',
#  'C0139741',
#  'C0139774',
#  'C0139796',
#  'C0139842',
#  'C0139925',
#  'C0139991',
#  'C0139998',
#  'C0140107',
#  'C0140345',
#  'C0140347',
#  'C0140500',
#  'C0140518',
#  'C0140559',
#  'C0140681',
#  'C0140692',
#  'C0140698',
#  'C0140761',
#  'C0140762',
#  'C0140968',
#  'C0141029',
#  'C0141126',
#  'C0141134',
#  'C0141225',
#  'C0141269',
#  'C0141354',
#  'C0141402',
#  'C0141515',
#  'C0141566',
#  'C0141582',
#  'C0141646',
#  'C0141723',
#  'C0141796',
#  'C0141915',
#  'C0142036',
#  'C0142045',
#  'C0142223',
#  'C0142243',
#  'C0142279',
#  'C0142294',
#  'C0142319',
#  'C0142354',
#  'C0142377',
#  'C0142395',
#  'C0142452',
#  'C0142495',
#  'C0142499',
#  'C0142583',
#  'C0142752',
#  'C0142798',
#  'C0142813',
#  'C0142823',
#  'C0142904',
#  'C0142933',
#  'C0142947',
#  'C0142972',
#  'C0142991',
#  'C0143152',
#  'C0143205',
#  'C0143222',
#  'C0143364',
#  'C0143367',
#  'C0143429',
#  'C0143445',
#  'C0143455',
#  'C0143533',
#  'C0143639',
#  'C0143650',
#  'C0143655',
#  'C0143686',
#  'C0143751',
#  'C0143784',
#  'C0143842',
#  'C0143858',
#  'C0143910',
#  'C0143950',
#  'C0143990',
#  'C0144000',
#  'C0144019',
#  'C0144111',
#  'C0144148',
#  'C0144354',
#  'C0144606',
#  'C0144616',
#  'C0144648',
#  'C0144669',
#  'C0144717',
#  'C0144777',
#  'C0145120',
#  'C0145123',
#  'C0145143',
#  'C0145210',
#  'C0145226',
#  'C0145280',
#  'C0145338',
#  'C0145450',
#  'C0145611',
#  'C0145750',
#  'C0145780',
#  'C0145788',
#  'C0145881',
#  'C0145891',
#  'C0145937',
#  'C0146009',
#  'C0146055',
#  'C0146119',
#  'C0146193',
#  'C0146210',
#  'C0146216',
#  'C0146234',
#  'C0146253',
#  'C0146258',
#  'C0146264',
#  'C0146296',
#  'C0146310',
#  'C0146363',
#  'C0146459',
#  'C0146585',
#  'C0146648',
#  'C0146695',
#  'C0146846',
#  'C0147171',
#  'C0147255',
#  'C0147258',
#  'C0147283',
#  'C0147299',
#  'C0147316',
#  'C0147344',
#  'C0147357',
#  'C0147436',
#  'C0147451',
#  'C0147480',
#  'C0147482',
#  'C0147545',
#  'C0147575',
#  'C0147686',
#  'C0147769',
#  'C0147861',
#  'C0147907',
#  'C0147914',
#  'C0147944',
#  'C0147955',
#  'C0148017',
#  'C0148073',
#  'C0148250',
#  'C0148274',
#  'C0148368',
#  'C0148379',
#  'C0148680',
#  'C0148687',
#  'C0148694',
#  'C0148736',
#  'C0148775',
#  'C0148935',
#  'C0149044',
#  'C0149095',
#  'C0149155',
#  'C0149232',
#  'C0149380',
#  'C0149433',
#  'C0149523',
#  'C0149540',
#  'C0149565',
#  'C0149641',
#  'C0149665',
#  'C0149748',
#  'C0149791',
#  'C0149809',
#  'C0149814',
#  'C0149831',
#  'C0149838',
#  'C0149918',
#  'C0150003',
#  'C0150042',
#  'C0150148',
#  'C0150217',
#  'C0150242',
#  'C0150417',
#  'C0150450',
#  'C0150609',
#  'C0150631',
#  'C0150640',
#  'C0150674',
#  'C0150682',
#  'C0150936',
#  'C0151034',
#  'C0151060',
#  'C0151077',
#  'C0151092',
#  'C0151112',
#  'C0151116',
#  'C0151183',
#  'C0151210',
#  'C0151223',
#  'C0151284',
#  'C0151380',
#  'C0151405',
#  'C0151422',
#  'C0151464',
#  'C0151490',
#  'C0151520',
#  'C0151576',
#  'C0151591',
#  'C0151721',
#  'C0151827',
#  'C0151835',
#  'C0151887',
#  'C0151926',
#  'C0151941',
#  'C0151997',
#  'C0152006',
#  'C0152029',
#  'C0152039',
#  'C0152063',
#  'C0152107',
#  'C0152112',
#  'C0152325',
#  'C0152336',
#  'C0152419',
#  'C0152432',
#  'C0152517',
#  'C0152568',
#  'C0152629',
#  'C0152642',
#  'C0152668',
#  'C0152675',
#  'C0152707',
#  'C0152724',
#  'C0152747',
#  'C0152791',
#  'C0152802',
#  'C0152804',
#  'C0152909',
#  'C0153052',
#  'C0153112',
#  'C0153122',
#  'C0153254',
#  'C0153262',
#  'C0153265',
#  'C0153291',
#  'C0153313',
#  'C0153443',
#  'C0153536',
#  'C0153595',
#  'C0153649',
#  'C0153676',
#  'C0153763',
#  'C0153782',
#  'C0153787',
#  'C0153836',
#  'C0153864',
#  'C0153929',
#  'C0154000',
#  'C0154008',
#  'C0154032',
#  'C0154300',
#  'C0154398',
#  'C0154419',
#  'C0154523',
#  'C0154543',
#  'C0154595',
#  'C0154698',
#  'C0154800',
#  'C0154870',
#  'C0154903',
#  'C0154938',
#  'C0154980',
#  'C0154998',
#  'C0155009',
#  'C0155104',
#  'C0155209',
#  'C0155225',
#  'C0155234',
#  'C0155422',
#  'C0155448',
#  'C0155555',
#  'C0155585',
#  'C0155634',
#  'C0155649',
#  'C0155677',
#  'C0155679',
#  'C0155731',
#  'C0155862',
#  'C0155875',
#  'C0155924',
#  'C0155944',
#  'C0155946',
#  'C0156033',
#  'C0156035',
#  'C0156161',
#  'C0156260',
#  'C0156370',
#  'C0156375',
#  'C0156411',
#  'C0156432',
#  'C0156468',
#  'C0156558',
#  'C0156565',
#  'C0156645',
#  'C0156688',
#  'C0156720',
#  'C0156797',
#  'C0156956',
#  'C0157036',
#  'C0157086',
#  'C0157099',
#  'C0157147',
#  'C0157209',
#  'C0157321',
#  'C0157356',
#  'C0157589',
#  'C0157834',
#  'C0157854',
#  'C0157958',
#  'C0157971',
#  'C0157974',
#  'C0158086',
#  'C0158158',
#  'C0158207',
#  'C0158217',
#  'C0158221',
#  'C0158281',
#  'C0158327',
#  'C0158481',
#  'C0158593',
#  'C0158634',
#  'C0158691',
#  'C0158896',
#  'C0158902',
#  'C0158954',
#  'C0159285',
#  'C0159358',
#  'C0159528',
#  'C0159534',
#  'C0159584',
#  'C0159625',
#  'C0159628',
#  'C0159782',
#  'C0159787',
#  'C0159835',
#  'C0159948',
#  'C0159960',
#  'C0159993',
#  'C0160041',
#  'C0160043',
#  'C0160217',
#  'C0160278',
#  'C0160367',
#  'C0160368',
#  'C0160390',
#  'C0160477',
#  'C0160493',
#  'C0160517',
#  'C0160565',
#  'C0160682',
#  'C0160742',
#  'C0160926',
#  'C0160941',
#  'C0161020',
#  'C0161039',
#  'C0161059',
#  'C0161261',
#  'C0161367',
#  'C0161391',
#  'C0161436',
#  'C0161548',
#  'C0161741',
#  'C0161768',
#  'C0161773',
#  'C0161836',
#  'C0161976',
#  'C0162028',
#  'C0162032',
#  'C0162064',
#  'C0162073',
#  'C0162145',
#  'C0162154',
#  'C0162181',
#  'C0162288',
#  'C0162307',
#  'C0162338',
#  'C0162361',
#  'C0162438',
#  'C0162518',
#  'C0162551',
#  'C0162558',
#  'C0162562',
#  'C0162636',
#  'C0162701',
#  'C0162735',
#  'C0162921',
#  'C0162931',
#  'C0162937',
#  'C0163026',
#  'C0163045',
#  'C0163046',
#  'C0163101',
#  'C0163109',
#  'C0163151',
#  'C0163167',
#  'C0163337',
#  'C0163390',
#  'C0163427',
#  'C0163605',
#  'C0163751',
#  'C0163786',
#  'C0163983',
#  'C0164031',
#  'C0164080',
#  'C0164105',
#  'C0164141',
#  'C0164169',
#  'C0164240',
#  'C0164336',
#  'C0164385',
#  'C0164428',
#  'C0164431',
#  'C0164452',
#  'C0164486',
#  'C0164650',
#  'C0164783',
#  'C0164807',
#  'C0164868',
#  'C0164915',
#  'C0164917',
#  'C0164981',
#  'C0165054',
#  'C0165059',
#  'C0165155',
#  'C0165181',
#  'C0165187',
#  'C0165322',
#  'C0165335',
#  'C0165393',
#  'C0165500',
#  'C0165545',
#  'C0165600',
#  'C0165639',
#  'C0165650',
#  'C0165727',
#  'C0165784',
#  'C0165834',
#  'C0165845',
#  'C0165849',
#  'C0165850',
#  'C0165920',
#  'C0165933',
#  'C0165973',
#  'C0166019',
#  'C0166124',
#  'C0166133',
#  'C0166157',
#  'C0166162',
#  'C0166199',
#  'C0166226',
#  'C0166250',
#  'C0166307',
#  'C0166309',
#  'C0166421',
#  'C0166521',
#  'C0166571',
#  'C0166581',
#  'C0166605',
#  'C0166619',
#  'C0166719',
#  'C0166727',
#  'C0166808',
#  'C0166999',
#  'C0167016',
#  'C0167030',
#  'C0167062',
#  'C0167179',
#  'C0167215',
#  'C0167377',
#  'C0167536',
#  'C0167627',
#  'C0167647',
#  'C0167788',
#  'C0167898',
#  'C0167902',
#  'C0167991',
#  'C0168039',
#  'C0168043',
#  'C0168046',
#  'C0168217',
#  'C0168225',
#  'C0168268',
#  'C0168429',
#  'C0168507',
#  'C0168518',
#  'C0168539',
#  'C0168588',
#  'C0168692',
#  'C0168771',
#  'C0168792',
#  'C0168809',
#  'C0168893',
#  'C0169013',
#  'C0169021',
#  'C0169077',
#  'C0169086',
#  'C0169130',
#  'C0169177',
#  'C0169373',
#  'C0169451',
#  'C0169729',
#  'C0169764',
#  'C0169771',
#  'C0169869',
#  'C0170002',
#  'C0170022',
#  'C0170056',
#  'C0170083',
#  'C0170128',
#  'C0170172',
#  'C0170187',
#  'C0170220',
#  'C0170238',
#  'C0170251',
#  'C0170319',
#  'C0170349',
#  'C0170365',
#  'C0170379',
#  'C0170602',
#  'C0170620',
#  'C0170661',
#  'C0170672',
#  'C0170699',
#  'C0170818',
#  'C0170833',
#  'C0170837',
#  'C0170838',
#  'C0170884',
#  'C0170941',
#  'C0171015',
#  'C0171037',
#  'C0171178',
#  'C0171198',
#  'C0171219',
#  'C0171245',
#  'C0171276',
#  'C0171413',
#  'C0171553',
#  'C0171713',
#  'C0171740',
#  'C0171748',
#  'C0171775',
#  'C0171878',
#  'C0171888',
#  'C0172060',
#  'C0172117',
#  'C0172347',
#  'C0172360',
#  'C0172450',
#  'C0172485',
#  'C0172553',
#  'C0172761',
#  'C0172940',
#  'C0172960',
#  'C0172971',
#  'C0172985',
#  'C0172989',
#  'C0173050',
#  'C0173061',
#  'C0173124',
#  'C0173130',
#  'C0173187',
#  'C0173197',
#  'C0173249',
#  'C0173261',
#  'C0173290',
#  'C0173404',
#  'C0173448',
#  'C0173460',
#  'C0173518',
#  'C0173587',
#  'C0173634',
#  'C0173641',
#  'C0173745',
#  'C0173802',
#  'C0173807',
#  'C0173816',
#  'C0173820',
#  'C0173887',
#  'C0174019',
#  'C0174101',
#  'C0174114',
#  'C0174121',
#  'C0174143',
#  'C0174156',
#  'C0174182',
#  'C0174249',
#  'C0174307',
#  'C0174317',
#  'C0174364',
#  'C0174619',
#  'C0174633',
#  'C0174678',
#  'C0174685',
#  'C0174850',
#  'C0174952',
#  'C0175025',
#  'C0175148',
#  'C0175200',
#  'C0175224',
#  'C0175405',
#  'C0175454',
#  'C0175455',
#  'C0175776',
#  'C0175835',
#  'C0176004',
#  'C0176029',
#  'C0176030',
#  'C0176065',
#  'C0176233',
#  'C0176236',
#  'C0176238',
#  'C0176240',
#  'C0176249',
#  'C0176389',
#  'C0176428',
#  'C0176534',
#  'C0176560',
#  'C0176565',
#  'C0176570',
#  'C0176608',
#  'C0176614',
#  'C0176627',
#  'C0176654',
#  'C0176655',
#  'C0176663',
#  'C0176711',
#  'C0176888',
#  'C0176895',
#  'C0176935',
#  'C0176941',
#  'C0176956',
#  'C0177092',
#  'C0177141',
#  'C0177349',
#  'C0177573',
#  'C0177635',
#  'C0177747',
#  'C0177753',
#  'C0177885',
#  'C0177892',
#  'C0178138',
#  'C0178148',
#  'C0178161',
#  'C0178362',
#  'C0178369',
#  'C0178424',
#  'C0178429',
#  'C0178449',
#  'C0178474',
#  'C0178561',
#  'C0178591',
#  'C0178686',
#  'C0178717',
#  'C0178796',
#  'C0178820',
#  'C0178851',
#  'C0179133',
#  'C0179153',
#  'C0179213',
#  'C0179255',
#  'C0179357',
#  'C0179423',
#  'C0179484',
#  'C0179530',
#  'C0179643',
#  'C0179697',
#  'C0179770',
#  'C0179835',
#  'C0179852',
#  'C0179855',
#  'C0179909',
#  'C0179944',
#  'C0180236',
#  'C0180329',
#  'C0180331',
#  'C0180346',
#  'C0180375',
#  'C0180459',
#  'C0180507',
#  'C0180523',
#  'C0180537',
#  'C0180557',
#  'C0180610',
#  'C0180611',
#  'C0180637',
#  'C0180739',
#  'C0180893',
#  'C0180895',
#  'C0181064',
#  'C0181065',
#  'C0181155',
#  'C0181254',
#  'C0181318',
#  'C0181322',
#  'C0181400',
#  'C0181403',
#  'C0181524',
#  'C0181525',
#  'C0181526',
#  'C0181574',
#  'C0181617',
#  'C0181762',
#  'C0181768',
#  'C0181898',
#  'C0181937',
#  'C0182046',
#  'C0182100',
#  'C0182157',
#  'C0182178',
#  'C0182259',
#  'C0182268',
#  'C0182270',
#  'C0182323',
#  'C0182333',
#  'C0182348',
#  'C0182362',
#  'C0182411',
#  'C0182460',
#  'C0182507',
#  'C0182509',
#  'C0182538',
#  'C0182588',
#  'C0182609',
#  'C0182817',
#  'C0182882',
#  'C0182899',
#  'C0182947',
#  'C0182971',
#  'C0183102',
#  'C0183137',
#  'C0183146',
#  'C0183219',
#  'C0183248',
#  'C0183384',
#  'C0183426',
#  'C0183443',
#  'C0183455',
#  'C0183630',
#  'C0183713',
#  'C0183740',
#  'C0183765',
#  'C0183918',
#  'C0184031',
#  'C0184219',
#  'C0184360',
#  'C0184423',
#  'C0184482',
#  'C0184551',
#  'C0184592',
#  'C0184594',
#  'C0184673',
#  'C0184746',
#  'C0184758',
#  'C0184924',
#  'C0185028',
#  'C0185098',
#  'C0185536',
#  'C0185577',
#  'C0185703',
#  'C0185762',
#  'C0185776',
#  'C0185945',
#  'C0185962',
#  'C0186151',
#  'C0186178',
#  'C0186308',
#  'C0186383',
#  'C0186607',
#  'C0186618',
#  'C0186659',
#  'C0186772',
#  'C0186775',
#  'C0186795',
#  'C0186833',
#  'C0186890',
#  'C0186924',
#  'C0186952',
#  'C0186970',
#  'C0186998',
#  'C0187104',
#  'C0187158',
#  'C0187194',
#  'C0187204',
#  'C0187410',
#  'C0187512',
#  'C0187575',
#  'C0187608',
#  'C0187617',
#  'C0187618',
#  'C0187646',
#  'C0187708',
#  'C0187823',
#  'C0187832',
#  'C0187917',
#  'C0188034',
#  'C0188042',
#  'C0188078',
#  'C0188085',
#  'C0188142',
#  'C0188174',
#  'C0188417',
#  'C0188533',
#  'C0188578',
#  'C0188806',
#  'C0188846',
#  'C0188895',
#  'C0188956',
#  'C0189015',
#  'C0189166',
#  'C0189283',
#  ...]
